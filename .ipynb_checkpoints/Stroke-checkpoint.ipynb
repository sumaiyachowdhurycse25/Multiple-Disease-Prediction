# %%
# loading the important libraries 

import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# read the dataset 
pd.set_option("display.max_columns", None)

df = pd.read_csv('Group4_healthcare-dataset-stroke-data.csv')
print(df.shape)
df.head()
# Out:
# (5110, 12)
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
for cols in df.columns:
    unique_vals = df[cols].unique()
    if len(unique_vals) <= 10:
        print("Feature ", cols, " has ", len(unique_vals), " unique values ----> ", unique_vals)
    else:
        print("Feature ", cols, " has ", len(unique_vals), " unique values")
# Out:
# Feature  id  has  5110  unique values
# Feature  gender  has  3  unique values ---->  ['Male' 'Female' 'Other']
# Feature  age  has  104  unique values
# Feature  hypertension  has  2  unique values ---->  [0 1]
# Feature  heart_disease  has  2  unique values ---->  [1 0]
# Feature  ever_married  has  2  unique values ---->  ['Yes' 'No']
# Feature  work_type  has  5  unique values ---->  ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# Feature  Residence_type  has  2  unique values ---->  ['Urban' 'Rural']
# Feature  avg_glucose_level  has  3979  unique values
# Feature  bmi  has  419  unique values
# Feature  smoking_status  has  4  unique values ---->  ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
# Feature  stroke  has  2  unique values ---->  [1 0]

# %% [markdown]
# # Data Pre-processing Phase

# %% [markdown]
# # EDA

# %%
## checking for null values
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# remove duplicate entries, if any
df.drop_duplicates(inplace = True)
print(df.shape)
# Out:
# (5110, 12)

# %%
#since bmi has 201 null values,replacing them with the mean value
df['bmi'].fillna(int(df['bmi'].mean()), inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21  28.0     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75  28.0     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
for colum in df.columns:
    
        print("Feature ", colum)
    
        print("value count ", df[colum].value_counts())
# Out:
# Feature  id
# value count  49152    1
# 21785    1
# 25982    1
# 5500     1
# 28027    1
#         ..
# 45759    1
# 4795     1
# 47802    1
# 49849    1
# 16380    1
# Name: id, Length: 5110, dtype: int64
# Feature  gender
# value count  Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64
# Feature  age
# value count  78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 0.48       3
# 1.40       3
# 0.16       3
# 0.08       2
# 0.40       2
# Name: age, Length: 104, dtype: int64
# Feature  hypertension
# value count  0    4612
# 1     498
# Name: hypertension, dtype: int64
# Feature  heart_disease
# value count  0    4834
# 1     276
# Name: heart_disease, dtype: int64
# Feature  ever_married
# value count  Yes    3353
# No     1757
# Name: ever_married, dtype: int64
# Feature  work_type
# value count  Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64
# Feature  Residence_type
# value count  Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64
# Feature  avg_glucose_level
# value count  93.88     6
# 72.49     5
# 84.10     5
# 91.68     5
# 83.16     5
#          ..
# 95.02     1
# 120.09    1
# 197.58    1
# 99.91     1
# 60.50     1
# Name: avg_glucose_level, Length: 3979, dtype: int64
# Feature  bmi
# value count  28.0    229
# 28.7     41
# 28.4     38
# 27.7     37
# 27.6     37
#        ...
# 48.0      1
# 49.4      1
# 47.4      1
# 46.6      1
# 54.0      1
# Name: bmi, Length: 418, dtype: int64
# Feature  smoking_status
# value count  never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64
# Feature  stroke
# value count  0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
for colm in df.columns:
       if len(df[colm].unique()) <= 30:
            
          print("Feature ", colm)
          df[colm].value_counts().plot(kind="bar")
          plt.show()
# Out:
# Feature  gender
# Feature  hypertension
# Feature  heart_disease
# Feature  ever_married
# Feature  work_type
# Feature  Residence_type
# Feature  smoking_status
# Feature  stroke

# %%
df.hist(figsize=(30,30))
plt.show()

# %%
sns.set(rc = {'figure.figsize':(30,30)})

# %%
sns.histplot(x = 'age', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
#feature age has no variance in both category

# %%
sns.histplot(x = 'gender', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
#female has lower chance of having stroke

# %%
sns.histplot(x = 'hypertension', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='Count'>

# %%
#people with no hypertension have
lower chance of having stroke

# %%
sns.histplot(x = 'heart_disease', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='Count'>

# %%
#people with no heart disease have 
lower chance of having stroke

# %%
sns.histplot(x = 'ever_married', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='ever_married', ylabel='Count'>

# %%
#married people have lower chance of having stroke

# %%
sns.histplot(x = 'work_type', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='Count'>

# %%
#people working in private farm have
lower chance of having stroke

# %%
sns.histplot(x = 'Residence_type', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='Residence_type', ylabel='Count'>

# %%
#Feature residence type has no
variance in both category

# %%
sns.histplot(x = 'avg_glucose_level', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='Count'>

# %%
#Feature avg_glucose_level has 
no variance in both category

# %%
sns.histplot(x = 'bmi', data = df, hue = 'stroke',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Count'>

# %%
#Feature bmi has no variance in both category

# %%
sns.scatterplot(df['age'],df['stroke'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='stroke'>

# %%
#For Feature age,the values before 
40 have higher frequency of having stroke

# %%
sns.scatterplot(df['avg_glucose_level'],df['stroke'])
# Out:
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='stroke'>

# %%
#For Feature avg_glucose_level,the values in the range 
140 to 160 have lower frequency of having stroke

# %%
sns.scatterplot(df['bmi'],df['stroke'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='stroke'>

# %%
#For Feature bmi,the values in the range 
20 to 50 have higher frequency of having stroke

# %%
sns.barplot( x=df['age'], y=df['gender'], hue=df['stroke'], ci=None )
plt.show()

# %%
#both male and female aged over 40 
have higher chance of having stroke

# %%
sns.barplot( x=df['gender'], y=df['avg_glucose_level'], hue=df['stroke'], ci=None )
plt.show()

# %%
#both male and female with average glucose level over 
110 have higher chance of having stroke

# %%
sns.barplot( x=df['heart_disease'], y=df['bmi'], hue=df['stroke'],ci=None )
plt.show()

# %%
#feature bmi and heart disease combinely have no variance

# %%
sns.barplot( x=df['work_type'], y=df['hypertension'], hue=df['stroke'],ci=None )
plt.show()

# %%
#self employed people with higher hypertension 
have higher chance of having stroke

# %%
sns.barplot( x=df['Residence_type'], y=df['bmi'], hue=df['stroke'],ci=None )
plt.show()

# %%
#feature bmi and Residence type combinely have no variance

# %% [markdown]
# #Checking outliers

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.858102     0.048728
# std            45.283560     7.699976     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.000000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.boxplot(figsize=(10,10))
plt.show()

# %%
# implementation of the Tukey's algorithm
def findOutliers(dataset):
    outliers = []
    Q2 = dataset.median()
    Q1 = dataset.describe()[4]
    Q3 = dataset.describe()[6]
    IQR = Q3 - Q1
    lf = Q1 - 1.5*IQR # lf = lower fence
    uf = Q3 + 1.5*IQR # Uf = Upper fence
    for x in dataset:
        if x < lf or x > uf:
            outliers.append(x)
    return outliers

# %%
findOutliers(df['age'])
# Out:
# []

# %%
sns.boxplot(x = 'age', data = df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
findOutliers(df['avg_glucose_level'])
# Out:
# [228.69,
#  202.21,
#  171.23,
#  174.12,
#  186.21,
#  219.84,
#  214.09,
#  191.61,
#  221.29,
#  217.08,
#  193.94,
#  233.29,
#  228.7,
#  208.3,
#  189.84,
#  195.23,
#  211.78,
#  212.08,
#  196.92,
#  252.72,
#  219.72,
#  213.03,
#  243.58,
#  197.54,
#  196.71,
#  237.75,
#  194.99,
#  180.93,
#  185.17,
#  221.58,
#  179.12,
#  228.56,
#  240.09,
#  226.98,
#  235.63,
#  240.59,
#  190.32,
#  231.61,
#  191.82,
#  224.1,
#  216.94,
#  259.63,
#  249.31,
#  219.91,
#  200.59,
#  190.14,
#  182.99,
#  206.09,
#  263.32,
#  207.28,
#  194.37,
#  199.2,
#  221.79,
#  239.07,
#  169.67,
#  223.83,
#  231.56,
#  221.89,
#  195.71,
#  203.87,
#  185.49,
#  213.22,
#  215.94,
#  209.86,
#  205.77,
#  271.74,
#  200.62,
#  242.52,
#  175.29,
#  208.65,
#  205.33,
#  210.4,
#  199.86,
#  219.73,
#  250.89,
#  205.35,
#  216.58,
#  184.4,
#  199.84,
#  218.46,
#  211.06,
#  197.28,
#  233.94,
#  247.51,
#  210.95,
#  243.53,
#  205.84,
#  198.21,
#  206.72,
#  214.45,
#  190.7,
#  203.04,
#  242.3,
#  220.49,
#  218.46,
#  216.7,
#  234.58,
#  235.85,
#  243.5,
#  182.2,
#  229.92,
#  215.6,
#  239.64,
#  200.28,
#  205.23,
#  209.58,
#  210.78,
#  251.6,
#  213.37,
#  223.36,
#  178.29,
#  203.81,
#  205.26,
#  211.03,
#  225.47,
#  180.63,
#  227.1,
#  201.76,
#  170.05,
#  217.3,
#  196.01,
#  184.15,
#  198.69,
#  186.17,
#  183.45,
#  210.48,
#  193.83,
#  183.34,
#  247.69,
#  191.47,
#  239.82,
#  189.57,
#  207.58,
#  182.86,
#  215.64,
#  196.36,
#  188.11,
#  205.5,
#  204.86,
#  228.08,
#  219.53,
#  219.97,
#  214.05,
#  200.49,
#  240.71,
#  197.1,
#  194.62,
#  222.21,
#  250.2,
#  173.43,
#  184.25,
#  254.6,
#  212.01,
#  186.45,
#  189.49,
#  186.32,
#  226.7,
#  183.1,
#  194.04,
#  237.15,
#  231.19,
#  207.32,
#  207.64,
#  236.84,
#  204.63,
#  232.89,
#  195.03,
#  170.95,
#  227.91,
#  204.5,
#  206.25,
#  254.63,
#  246.34,
#  195.16,
#  223.68,
#  229.2,
#  193.22,
#  204.57,
#  251.46,
#  220.52,
#  195.04,
#  218.65,
#  211.49,
#  224.71,
#  226.11,
#  210.94,
#  230.68,
#  198.02,
#  204.17,
#  267.76,
#  217.71,
#  180.76,
#  239.52,
#  229.86,
#  210.96,
#  195.25,
#  217.39,
#  201.25,
#  197.79,
#  214.77,
#  181.23,
#  189.45,
#  206.4,
#  178.76,
#  197.58,
#  199.96,
#  205.77,
#  237.21,
#  246.53,
#  206.33,
#  206.98,
#  227.28,
#  228.7,
#  169.97,
#  244.28,
#  251.99,
#  191.79,
#  216.88,
#  222.29,
#  213.11,
#  227.51,
#  201.01,
#  210.0,
#  237.58,
#  207.45,
#  226.93,
#  253.16,
#  238.53,
#  207.79,
#  196.2,
#  231.76,
#  216.92,
#  194.98,
#  218.54,
#  183.0,
#  237.17,
#  178.33,
#  197.09,
#  242.84,
#  202.66,
#  216.9,
#  210.0,
#  208.05,
#  222.6,
#  199.14,
#  191.48,
#  200.16,
#  190.4,
#  215.9,
#  233.52,
#  213.54,
#  188.69,
#  219.5,
#  217.66,
#  227.16,
#  209.9,
#  176.48,
#  211.88,
#  225.6,
#  210.23,
#  234.82,
#  230.59,
#  224.63,
#  185.71,
#  208.17,
#  185.31,
#  203.04,
#  187.87,
#  213.87,
#  222.85,
#  198.36,
#  196.25,
#  194.53,
#  204.05,
#  199.18,
#  209.26,
#  217.11,
#  222.46,
#  187.52,
#  237.74,
#  223.35,
#  201.07,
#  208.06,
#  186.95,
#  198.24,
#  229.21,
#  209.06,
#  228.42,
#  212.97,
#  202.05,
#  206.25,
#  231.69,
#  219.96,
#  197.69,
#  199.88,
#  170.22,
#  208.78,
#  222.29,
#  220.36,
#  187.88,
#  191.66,
#  217.75,
#  226.88,
#  186.4,
#  169.49,
#  203.81,
#  170.76,
#  189.44,
#  249.29,
#  211.35,
#  206.59,
#  196.33,
#  242.94,
#  226.75,
#  185.0,
#  199.83,
#  227.81,
#  240.81,
#  239.28,
#  231.5,
#  192.37,
#  220.47,
#  196.91,
#  180.8,
#  247.48,
#  216.0,
#  219.39,
#  220.47,
#  173.96,
#  198.33,
#  191.33,
#  206.52,
#  216.96,
#  170.93,
#  232.81,
#  207.95,
#  229.58,
#  187.22,
#  227.04,
#  214.42,
#  233.71,
#  216.4,
#  266.59,
#  227.94,
#  205.0,
#  203.44,
#  243.73,
#  176.25,
#  200.28,
#  221.43,
#  213.38,
#  192.16,
#  215.72,
#  173.14,
#  202.57,
#  209.5,
#  203.16,
#  201.45,
#  206.15,
#  196.61,
#  219.92,
#  231.95,
#  216.38,
#  213.33,
#  172.33,
#  243.59,
#  169.43,
#  183.87,
#  227.98,
#  208.2,
#  199.42,
#  190.13,
#  235.54,
#  178.89,
#  227.74,
#  213.8,
#  250.8,
#  217.84,
#  217.0,
#  217.4,
#  190.92,
#  182.9,
#  255.17,
#  217.55,
#  227.96,
#  231.71,
#  196.81,
#  222.66,
#  223.58,
#  198.79,
#  192.39,
#  233.3,
#  201.38,
#  236.14,
#  193.81,
#  239.95,
#  170.88,
#  202.21,
#  181.3,
#  198.79,
#  202.55,
#  232.12,
#  203.57,
#  230.78,
#  204.98,
#  227.89,
#  216.71,
#  202.67,
#  221.8,
#  202.38,
#  215.81,
#  220.24,
#  195.61,
#  267.61,
#  176.71,
#  207.62,
#  201.58,
#  231.43,
#  220.26,
#  211.12,
#  177.91,
#  215.33,
#  212.02,
#  228.2,
#  260.85,
#  223.9,
#  169.74,
#  207.96,
#  176.78,
#  205.01,
#  191.78,
#  214.43,
#  220.64,
#  204.77,
#  248.37,
#  194.53,
#  228.92,
#  227.68,
#  226.73,
#  219.17,
#  215.92,
#  198.12,
#  240.86,
#  263.56,
#  200.14,
#  235.45,
#  207.71,
#  228.05,
#  223.14,
#  174.43,
#  214.51,
#  231.31,
#  238.78,
#  233.59,
#  188.13,
#  205.97,
#  190.89,
#  193.87,
#  214.77,
#  189.88,
#  197.11,
#  192.47,
#  199.38,
#  202.98,
#  198.32,
#  226.38,
#  236.79,
#  219.82,
#  239.19,
#  206.62,
#  216.88,
#  204.92,
#  226.84,
#  234.35,
#  200.73,
#  202.51,
#  218.0,
#  209.15,
#  202.66,
#  196.5,
#  209.5,
#  219.81,
#  205.23,
#  234.27,
#  239.21,
#  196.08,
#  176.38,
#  175.74,
#  193.45,
#  180.45,
#  219.38,
#  173.9,
#  217.94,
#  216.64,
#  173.97,
#  208.85,
#  219.7,
#  208.05,
#  185.28,
#  198.3,
#  206.66,
#  200.68,
#  218.6,
#  223.26,
#  172.27,
#  221.83,
#  218.1,
#  200.46,
#  217.79,
#  233.47,
#  181.23,
#  200.98,
#  219.67,
#  207.6,
#  247.97,
#  231.15,
#  186.54,
#  221.06,
#  212.62,
#  217.74,
#  208.99,
#  197.36,
#  222.52,
#  232.64,
#  207.37,
#  201.96,
#  213.43,
#  248.24,
#  229.94,
#  202.06,
#  253.93,
#  194.75,
#  207.84,
#  228.26,
#  203.76,
#  205.78,
#  179.67,
#  230.74,
#  216.19,
#  200.66,
#  228.5,
#  232.29,
#  200.91,
#  236.04,
#  254.95,
#  196.58,
#  189.82,
#  193.61,
#  195.74,
#  221.24,
#  192.5,
#  212.92,
#  191.94,
#  247.87,
#  229.73,
#  261.67,
#  256.74,
#  221.08,
#  208.39,
#  227.23,
#  203.27,
#  234.5,
#  190.67,
#  197.06,
#  216.07,
#  179.14,
#  203.87,
#  235.06,
#  195.43,
#  200.25,
#  223.64,
#  199.78,
#  176.42,
#  244.3,
#  223.16,
#  226.28,
#  172.86,
#  213.92,
#  212.19,
#  200.8,
#  222.58,
#  206.53,
#  232.78,
#  187.47,
#  234.06,
#  242.62,
#  174.54,
#  231.54,
#  219.8,
#  187.99,
#  234.45,
#  240.69,
#  217.57,
#  234.51,
#  182.22,
#  214.73,
#  208.69,
#  231.72,
#  206.53,
#  193.8,
#  203.01,
#  177.56,
#  198.84,
#  243.52,
#  238.27,
#  208.31,
#  176.34,
#  211.83,
#  215.69,
#  267.6,
#  215.07,
#  225.35,
#  196.26,
#  182.52,
#  212.87,
#  183.43,
#  185.27,
#  206.49,
#  253.86,
#  203.36,
#  175.92,
#  191.15,
#  223.78,
#  211.58,
#  179.38,
#  193.88,
#  174.37]

# %%
sns.boxplot(x = 'avg_glucose_level', data = df)
# Out:
# <AxesSubplot:xlabel='avg_glucose_level'>

# %%
Q1 = df['avg_glucose_level'].quantile(0.25)
Q3 = df['avg_glucose_level'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['avg_glucose_level']=np.where(df['avg_glucose_level']>upper_whisker,upper_whisker,np.where(df['avg_glucose_level']<lower_whisker,lower_whisker,df['avg_glucose_level']))

# %%
sns.boxplot(x = 'avg_glucose_level', data = df)
# Out:
# <AxesSubplot:xlabel='avg_glucose_level'>

# %%
findOutliers(df['bmi'])
# Out:
# [48.9,
#  47.5,
#  56.6,
#  50.1,
#  54.6,
#  60.9,
#  54.7,
#  48.2,
#  64.8,
#  47.3,
#  46.5,
#  46.6,
#  54.7,
#  49.8,
#  60.2,
#  51.0,
#  51.5,
#  71.9,
#  50.2,
#  47.8,
#  54.6,
#  55.7,
#  55.7,
#  57.5,
#  54.2,
#  52.3,
#  50.3,
#  78.0,
#  50.2,
#  53.4,
#  55.2,
#  48.4,
#  50.6,
#  49.5,
#  55.0,
#  54.8,
#  50.2,
#  47.5,
#  52.8,
#  66.8,
#  55.1,
#  48.5,
#  55.9,
#  57.3,
#  10.3,
#  49.8,
#  56.0,
#  51.8,
#  57.7,
#  48.9,
#  49.3,
#  49.8,
#  54.0,
#  56.1,
#  97.6,
#  53.9,
#  49.4,
#  48.5,
#  49.2,
#  48.7,
#  48.9,
#  53.8,
#  46.5,
#  48.8,
#  52.7,
#  52.8,
#  55.7,
#  53.5,
#  50.5,
#  51.9,
#  63.3,
#  52.8,
#  61.2,
#  48.0,
#  46.8,
#  50.1,
#  48.3,
#  58.1,
#  49.3,
#  50.4,
#  52.7,
#  48.3,
#  49.3,
#  51.9,
#  53.4,
#  50.3,
#  59.7,
#  47.4,
#  52.5,
#  52.9,
#  54.7,
#  61.6,
#  49.9,
#  53.8,
#  47.3,
#  54.3,
#  47.9,
#  55.0,
#  50.9,
#  50.6,
#  57.2,
#  64.4,
#  92.0,
#  50.8,
#  55.9,
#  57.9,
#  47.6,
#  55.7,
#  48.8,
#  57.2,
#  47.5,
#  46.4,
#  46.9,
#  50.2,
#  47.1,
#  48.1,
#  51.7,
#  60.9,
#  47.8,
#  47.6,
#  46.3,
#  54.1,
#  56.6,
#  49.5,
#  47.6,
#  46.9]

# %%
sns.boxplot(x = 'bmi', data = df)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
Q1 = df['bmi'].quantile(0.25)
Q3 = df['bmi'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['bmi']=np.where(df['bmi']>upper_whisker,upper_whisker,np.where(df['bmi']<lower_whisker,lower_whisker,df['bmi']))

# %%
sns.boxplot(x = 'bmi', data = df)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.pairplot(df,hue='stroke')

# %%
sns.pairplot(df, hue ='stroke', vars=['age', 'bmi'], height=6, aspect=1 )

# %%
sns.pairplot(df, hue ='stroke', vars=['age', 'avg_glucose_level'], height=6, aspect=1 )

# %%
sns.pairplot(df, hue ='stroke', vars=['bmi', 'avg_glucose_level'], height=6, aspect=1 )

# %% [markdown]
# #Note:we dont need to do data manupulation as our data is already well organised and in csv file.we dont need to do data blending as it means of merging several csv files but we have only 1 csv file.Feature generation means generating more features.We have 37 features already.We can't generate more features for this dataset

# %%
# Convert Catergorical values to numeric representation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
categ = ['gender','ever_married','work_type','Residence_type','smoking_status']

# Encode Categorical Columns
le = LabelEncoder()
df[categ] = df[categ].apply(le.fit_transform)

# %%
df.drop(columns = 'id', axis=1, inplace=True)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                  1           169.3575  36.6               1       1
# 1                  0           169.3575  28.0               2       1
# 2                  0           105.9200  32.5               2       1
# 3                  1           169.3575  34.4               3       1
# 4                  0           169.3575  24.0               2       1
# ...              ...                ...   ...             ...     ...
# 5105               1            83.7500  28.0               2       0
# 5106               1           125.2000  40.0               2       0
# 5107               0            82.9900  30.6               2       0
# 5108               0           166.2900  25.6               1       0
# 5109               1            85.2800  26.2               0       0
#
# [5110 rows x 11 columns]

# %% [markdown]
# # Partitioning

# %%
X = df.drop('stroke',axis=1)

# %%
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# 0                  1           169.3575  36.6               1
# 1                  0           169.3575  28.0               2
# 2                  0           105.9200  32.5               2
# 3                  1           169.3575  34.4               3
# 4                  0           169.3575  24.0               2
# ...              ...                ...   ...             ...
# 5105               1            83.7500  28.0               2
# 5106               1           125.2000  40.0               2
# 5107               0            82.9900  30.6               2
# 5108               0           166.2900  25.6               1
# 5109               1            85.2800  26.2               0
#
# [5110 rows x 10 columns]

# %%
Y= df['stroke']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
Y.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
#We can see there's an imbalaned class problem.There are less proportion of enrolled

# %%
#HoldOut Validation Approach - Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 0)

# %%
y_test.value_counts()
# Out:
# 0    1457
# 1      76
# Name: stroke, dtype: int64

# %%
#Stratified Train Test Split

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X, Y, test_size = 0.30, random_state = 0, stratify = Y)

# %%
y1_train.value_counts()
# Out:
# 0    3403
# 1     174
# Name: stroke, dtype: int64

# %%
y1_test.value_counts()
# Out:
# 0    1458
# 1      75
# Name: stroke, dtype: int64

# %% [markdown]
# # Normalization

# %%
# Feature Scaling

# %%
#We always scale the features in the range between 0 to 1 after partitioning

# %%
X.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  5110.000000  5110.000000   5110.000000    5110.000000   5110.000000
# mean      0.414286    43.226614      0.097456       0.054012      0.656164
# std       0.493044    22.612647      0.296607       0.226063      0.475034
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       2.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  5110.000000     5110.000000        5110.000000  5110.000000
# mean      2.167710        0.508023         100.996204    28.686477
# std       1.090293        0.499985          33.214738     7.121211
# min       0.000000        0.000000          55.120000    10.300000
# 25%       2.000000        0.000000          77.245000    23.800000
# 50%       2.000000        1.000000          91.885000    28.000000
# 75%       3.000000        1.000000         114.090000    32.800000
# max       4.000000        1.000000         169.357500    46.300000
#
#        smoking_status
# count     5110.000000
# mean         1.376908
# std          1.071534
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000

# %%
scale_vars = []

for cols in X.columns:
    if X[cols].max() > 1:
        scale_vars.append(cols)
scale_vars
# Out:
# ['gender', 'age', 'work_type', 'avg_glucose_level', 'bmi', 'smoking_status']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#We will scale based on X_train and then transform both X_train and X_test

# %%
scaler.fit(X_train[scale_vars])
X_train[scale_vars] = scaler.transform(X_train[scale_vars])
X_test[scale_vars] = scaler.transform(X_test[scale_vars])

# %%
X_test.head()
# Out:
#       gender       age  hypertension  heart_disease  ever_married  work_type  \
# 42       0.5  1.000000             0              1             1        0.5
# 380      0.5  0.047852             0              0             0        1.0
# 3524     0.5  0.707031             0              0             1        0.5
# 352      0.0  0.243164             0              0             0        0.5
# 4927     0.0  0.121094             0              0             0        1.0
#
#       Residence_type  avg_glucose_level       bmi  smoking_status
# 42                 1           0.785907  0.447222        1.000000
# 380                0           0.447314  0.177778        0.000000
# 3524               1           0.217354  0.433333        0.666667
# 352                0           0.362841  0.661111        0.666667
# 4927               0           0.128854  0.094444        0.000000

# %%
X_train.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  3577.000000  3577.000000   3577.000000    3577.000000   3577.000000
# mean      0.204361     0.526808      0.097288       0.054235      0.654739
# std       0.246117     0.276642      0.296391       0.226513      0.475520
# min       0.000000     0.000000      0.000000       0.000000      0.000000
# 25%       0.000000     0.304199      0.000000       0.000000      0.000000
# 50%       0.000000     0.548340      0.000000       0.000000      1.000000
# 75%       0.500000     0.743652      0.000000       0.000000      1.000000
# max       1.000000     1.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  3577.000000     3577.000000        3577.000000  3577.000000
# mean      0.539279        0.513559           0.402234     0.507098
# std       0.276165        0.499886           0.290163     0.198639
# min       0.000000        0.000000           0.000000     0.000000
# 25%       0.500000        0.000000           0.194770     0.369444
# 50%       0.500000        1.000000           0.323361     0.491667
# 75%       0.750000        1.000000           0.517256     0.619444
# max       1.000000        1.000000           1.000000     1.000000
#
#        smoking_status
# count     3577.000000
# mean         0.458019
# std          0.357335
# min          0.000000
# 25%          0.000000
# 50%          0.666667
# 75%          0.666667
# max          1.000000

# %%
X_test.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  1533.000000  1533.000000   1533.000000    1533.000000   1533.000000
# mean      0.213633     0.526421      0.097847       0.053490      0.659491
# std       0.247422     0.274698      0.297205       0.225082      0.474035
# min       0.000000     0.000977      0.000000       0.000000      0.000000
# 25%       0.000000     0.316406      0.000000       0.000000      0.000000
# 50%       0.000000     0.548340      0.000000       0.000000      1.000000
# 75%       0.500000     0.731445      0.000000       0.000000      1.000000
# max       0.500000     1.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  1533.000000     1533.000000        1533.000000  1533.000000
# mean      0.548108        0.495108           0.400075     0.519223
# std       0.263988        0.500139           0.292211     0.195669
# min       0.000000        0.000000           0.000875     0.083333
# 25%       0.500000        0.000000           0.190568     0.380556
# 50%       0.500000        0.000000           0.319072     0.500000
# 75%       0.750000        1.000000           0.514279     0.638889
# max       1.000000        1.000000           1.000000     1.000000
#
#        smoking_status
# count     1533.000000
# mean         0.461187
# std          0.356919
# min          0.000000
# 25%          0.000000
# 50%          0.666667
# 75%          0.666667
# max          1.000000

# %% [markdown]
# # Feature Selection

# %%
X_train.head()
# Out:
#       gender       age  hypertension  heart_disease  ever_married  work_type  \
# 1921     0.5  0.536133             0              0             1        0.5
# 4074     0.0  0.853516             0              0             1        0.0
# 2311     0.0  0.013184             0              0             0        1.0
# 3080     0.0  0.902344             0              0             1        0.5
# 1620     0.0  0.804688             0              0             1        0.0
#
#       Residence_type  avg_glucose_level       bmi  smoking_status
# 1921               0           0.353124  0.586111        1.000000
# 4074               0           0.903469  0.644444        0.666667
# 2311               1           0.086574  0.186111        0.000000
# 3080               0           0.249130  0.219444        0.666667
# 1620               0           0.266112  0.547222        0.666667

# %%
#Algorithm 3 - Feature Selection using Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif

mutual_info = mutual_info_classif(X_train, y_train, random_state = 20)
mutual_info
# Out:
# array([0.00268215, 0.0454184 , 0.00865925, 0.01187944, 0.00468844,
#        0.0019678 , 0.00139884, 0.00048144, 0.01113888, 0.0030414 ])

# %%
print(len(mutual_info))
print(X_train.shape)
# Out:
# 10
# (3577, 10)

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# age                  0.045418
# heart_disease        0.011879
# bmi                  0.011139
# hypertension         0.008659
# ever_married         0.004688
# smoking_status       0.003041
# gender               0.002682
# work_type            0.001968
# Residence_type       0.001399
# avg_glucose_level    0.000481
# dtype: float64

# %%
plt.figure(figsize = (30, 30))
mutual_info.sort_values(ascending = False).plot.bar();

# %%
#Algorithm 4 - Feature Selection using RFECV (Recursive Feature Elimination with Cross Validation)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings('ignore')

rfc = RandomForestClassifier(random_state=101)
rfecv = RFECV(estimator=rfc, step=1, cv=StratifiedKFold(5), scoring='accuracy')
rfecv.fit(X_train, y_train)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(random_state=101), scoring='accuracy')

# %%
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 8

# %%
plt.figure(figsize=(30, 30))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_, color='#303F9F', linewidth=3)
plt.show()

# %%
print(np.where(rfecv.support_ == False)[0])
# Out:
# [2 4]

# %%
selected_features = X_train.drop(X_train.columns[np.where(rfecv.support_ == False)[0]], axis=1)

# %%
rfecv.estimator_.feature_importances_
# Out:
# array([0.03451266, 0.27178129, 0.02997604, 0.05930294, 0.03579897,
#        0.22492539, 0.2701959 , 0.07350681])

# %%
dset = pd.DataFrame()
dset['attr'] = selected_features.columns
dset['importance'] = rfecv.estimator_.feature_importances_
dset = dset.sort_values(by='importance', ascending=False)

plt.figure(figsize=(30, 30))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %%
dset
# Out:
#                 attr  importance
# 1                age    0.271781
# 6                bmi    0.270196
# 5  avg_glucose_level    0.224925
# 7     smoking_status    0.073507
# 3          work_type    0.059303
# 4     Residence_type    0.035799
# 0             gender    0.034513
# 2      heart_disease    0.029976

# %%
#Algorithm 1 - Dropping Constant Features using Variance Threshold Technique

# %%
from sklearn.feature_selection import VarianceThreshold
# By default, the threshold = 0 i.e. it will remove the zero-variance threshold
var_thresh = VarianceThreshold() # by default the threshold = 0
var_thresh.fit(X_train)
# Out:
# VarianceThreshold()

# %%
print("Features Selected: ", X_train.columns[var_thresh.get_support()])
# Out:
# Features Selected:  Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
len(X_train.columns[var_thresh.get_support()])
# Out:
# 10

# %%
#There's no feature with zero variance

# %%
#Algorithm 2 - Feature Selection with Pearson's correlation

# %%
#Idea Highly correlated features with the target variable are important features, High correlation between features, (say over 90% or over 80%) indicate the existence of duplicate features.In case of duplicate features, we do not need to take all the features but one one of them would suffice

# %%
# Let's find the feature correlations

corr = X_train.corr()
corr

# Note that the correlation values lie between -1 and +1
# A correlation value close to -1 indicates a strong negative linear correlation
# A correlation value close to +1 indicates a strong positive linear correlation
# A correlation value close to 0 indicates no linear correlation
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000 -0.025444      0.032133       0.077017
# age               -0.025444  1.000000      0.280677       0.267376
# hypertension       0.032133  0.280677      1.000000       0.108822
# heart_disease      0.077017  0.267376      0.108822       1.000000
# ever_married      -0.021777  0.677536      0.145140       0.114183
# work_type          0.050553 -0.360493     -0.043282      -0.027359
# Residence_type    -0.008891  0.033899      0.000531      -0.004027
# avg_glucose_level  0.066053  0.188475      0.157976       0.141259
# bmi               -0.011867  0.351589      0.152307       0.050433
# smoking_status    -0.062465  0.260973      0.114264       0.046564
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                -0.021777   0.050553       -0.008891           0.066053
# age                    0.677536  -0.360493        0.033899           0.188475
# hypertension           0.145140  -0.043282        0.000531           0.157976
# heart_disease          0.114183  -0.027359       -0.004027           0.141259
# ever_married           1.000000  -0.351870        0.013229           0.128062
# work_type             -0.351870   1.000000       -0.018545          -0.041312
# Residence_type         0.013229  -0.018545        1.000000          -0.004559
# avg_glucose_level      0.128062  -0.041312       -0.004559           1.000000
# bmi                    0.357975  -0.323644        0.011258           0.149564
# smoking_status         0.250129  -0.311998        0.008797           0.056193
#
#                         bmi  smoking_status
# gender            -0.011867       -0.062465
# age                0.351589        0.260973
# hypertension       0.152307        0.114264
# heart_disease      0.050433        0.046564
# ever_married       0.357975        0.250129
# work_type         -0.323644       -0.311998
# Residence_type     0.011258        0.008797
# avg_glucose_level  0.149564        0.056193
# bmi                1.000000        0.240304
# smoking_status     0.240304        1.000000

# %%
plt.figure(figsize = (30,30))
sns.heatmap(corr, annot = True, cmap = "seismic");

# %%
# use of the mask 
import numpy as np
mask1 = np.triu(np.ones_like(corr, dtype=bool))
mask2 = np.tril(np.ones_like(corr, dtype=bool))
plt.figure(figsize = (30,30))
sns.heatmap(corr, annot = True, cmap = "seismic", mask = mask1);

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is highly correlated with another feature

def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of the redundant columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i, j])) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.85) # 85% is a good value of the threshold
print(len(corr_features))
print(corr_features)
# Out:
# 0
# set()

# %%
X_train.drop(columns = 'Residence_type', axis=1, inplace=True)
X_test.drop(columns = 'Residence_type', axis=1, inplace=True)

print(X_train)
print(X_test)
# Out:
#       gender       age  hypertension  heart_disease  ever_married  work_type  \
# 1921     0.5  0.536133             0              0             1        0.5
# 4074     0.0  0.853516             0              0             1        0.0
# 2311     0.0  0.013184             0              0             0        1.0
# 3080     0.0  0.902344             0              0             1        0.5
# 1620     0.0  0.804688             0              0             1        0.0
# ...      ...       ...           ...            ...           ...        ...
# 4931     0.0  0.645996             1              0             1        0.0
# 3264     0.0  0.743652             0              0             1        0.5
# 1653     0.5  0.536133             0              0             1        0.5
# 2607     0.5  0.255371             0              0             0        0.5
# 2732     0.0  0.707031             1              0             1        0.0
#
#       avg_glucose_level       bmi  smoking_status
# 1921           0.353124  0.586111        1.000000
# 4074           0.903469  0.644444        0.666667
# 2311           0.086574  0.186111        0.000000
# 3080           0.249130  0.219444        0.666667
# 1620           0.266112  0.547222        0.666667
# ...                 ...       ...             ...
# 4931           0.380698  0.791667        1.000000
# 3264           0.147850  0.436111        0.333333
# 1653           0.346559  0.502778        1.000000
# 2607           0.576168  0.538889        0.333333
# 2732           0.038516  0.636111        0.666667
#
# [3577 rows x 9 columns]
#       gender       age  hypertension  heart_disease  ever_married  work_type  \
# 42       0.5  1.000000             0              1             1       0.50
# 380      0.5  0.047852             0              0             0       1.00
# 3524     0.5  0.707031             0              0             1       0.50
# 352      0.0  0.243164             0              0             0       0.50
# 4927     0.0  0.121094             0              0             0       1.00
# ...      ...       ...           ...            ...           ...        ...
# 929      0.5  0.914551             0              1             1       0.75
# 2629     0.0  0.548340             0              0             1       0.50
# 663      0.0  0.462891             0              0             1       0.50
# 2303     0.0  0.914551             0              0             1       0.00
# 3122     0.0  0.694824             1              0             1       0.75
#
#       avg_glucose_level       bmi  smoking_status
# 42             0.785907  0.447222        1.000000
# 380            0.447314  0.177778        0.000000
# 3524           0.217354  0.433333        0.666667
# 352            0.362841  0.661111        0.666667
# 4927           0.128854  0.094444        0.000000
# ...                 ...       ...             ...
# 929            1.000000  0.561111        0.333333
# 2629           1.000000  0.972222        0.333333
# 663            0.381749  0.388889        0.666667
# 2303           1.000000  0.641667        1.000000
# 3122           0.075282  0.708333        1.000000
#
# [1533 rows x 9 columns]

# %%
X1_train.drop(columns = 'Residence_type', axis=1, inplace=True)
X1_test.drop(columns = 'Residence_type', axis=1, inplace=True)

print(X1_train)
print(X1_test)
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 262        0  37.0             0              0             1          2
# 1740       0  38.0             1              0             1          2
# 4010       0  30.0             0              0             1          3
# 2278       1  42.0             0              0             1          2
# 2958       1  16.0             0              0             0          2
# ...      ...   ...           ...            ...           ...        ...
# 1202       1  80.0             0              0             0          3
# 4655       0  10.0             0              0             0          4
# 3126       1  54.0             0              0             1          3
# 3896       0  31.0             0              0             0          2
# 1099       1  34.0             0              0             1          2
#
#       avg_glucose_level   bmi  smoking_status
# 262             73.5000  26.1               1
# 1740           137.9400  41.8               2
# 4010            76.7000  24.2               2
# 2278           145.5000  31.8               1
# 2958            90.3900  26.5               2
# ...                 ...   ...             ...
# 1202           169.3575  41.3               1
# 4655            57.2800  15.4               2
# 3126           114.6100  40.1               1
# 3896           102.3900  22.9               3
# 1099            85.5700  26.8               0
#
# [3577 rows x 9 columns]
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 4075       0   8.0             0              0             0          4
# 4277       0   2.0             0              0             0          4
# 2376       1  56.0             0              0             1          2
# 2162       0  47.0             0              0             1          0
# 2513       1  28.0             0              0             0          2
# ...      ...   ...           ...            ...           ...        ...
# 45         1  76.0             1              0             1          2
# 4850       1  14.0             0              0             0          4
# 3845       0  42.0             0              0             1          0
# 4908       0  69.0             0              0             1          3
# 1664       0  68.0             0              0             1          2
#
#       avg_glucose_level   bmi  smoking_status
# 4075           102.5000  16.3               0
# 4277           126.1200  24.8               0
# 2376            86.3600  27.7               1
# 2162           122.3200  23.9               0
# 2513            75.5000  27.0               3
# ...                 ...   ...             ...
# 45             169.3575  33.6               2
# 4850            99.8700  25.2               0
# 3845            99.9400  33.4               2
# 4908            67.5500  38.1               0
# 1664           103.4600  35.9               2
#
# [1533 rows x 9 columns]

# %% [markdown]
# # Model Creation and Evaluation

# %%
from sklearn import metrics

# %% [markdown]
# # With train-test split

# %% [markdown]
# # ZeroR classifier

# %%
# ZeroR classifier

from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score
zerort = DummyClassifier(strategy = "most_frequent")
zerort.fit(X_train, y_train)
y_pred_train = zerort.predict(X_train)
y_pred_test = zerort.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9504240052185258

# %%
ac_zero1 = accuracy_score(y_pred_test, y_test)

# %%
ac_zero1
# Out:
# 0.9504240052185258

# %%
#As there is class imbalance issue,we need classification report as well

# %%
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1457    0]
#  [  76    0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.950     1.000     0.975      1457
#            1      0.000     0.000     0.000        76
#
#     accuracy                          0.950      1533
#    macro avg      0.475     0.500     0.487      1533
# weighted avg      0.903     0.950     0.926      1533

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt1=accuracy_score(y_test,Y_pred)

# %%
ac_dt1
# Out:
# 0.9165035877364645

# %%
# Decision Tree analysis with the depth

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
maxdepths = [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]
trainAcc = np.zeros(len(maxdepths))
testAcc = np.zeros(len(maxdepths))

index = 0
for depth in maxdepths:
    dtn = DecisionTreeClassifier(max_depth=depth)
    dtn = dtn.fit(X_train, y_train)
    y_predTrain = dtn.predict(X_train)
    y_predTest = dtn.predict(X_test)
    trainAcc[index] = accuracy_score(y_train, y_predTrain)
    testAcc[index] = accuracy_score(y_test, y_predTest)
    print("Depth = ", depth, ", Training Accuracy = ", trainAcc[index], ", Test Accuracy = ", testAcc[index], 
          ", Diff = ", np.abs((trainAcc[index]-testAcc[index])*100), " %")
    index += 1

    
#########################################
# Plot of training and test accuracies
#########################################
    
plt.plot(maxdepths,trainAcc,'ro-',maxdepths,testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy');
# Out:
# Depth =  2 , Training Accuracy =  0.9516354487000279 , Test Accuracy =  0.9504240052185258 , Diff =  0.12114434815021502  %
# Depth =  3 , Training Accuracy =  0.9527537042214146 , Test Accuracy =  0.949119373776908 , Diff =  0.36343304445065616  %
# Depth =  4 , Training Accuracy =  0.9530332681017613 , Test Accuracy =  0.949119373776908 , Diff =  0.3913894324853229  %
# Depth =  5 , Training Accuracy =  0.9552697791445345 , Test Accuracy =  0.9465101108936725 , Diff =  0.8759668250861941  %
# Depth =  6 , Training Accuracy =  0.9580654179480012 , Test Accuracy =  0.9458577951728636 , Diff =  1.2207622775137539  %
# Depth =  7 , Training Accuracy =  0.9636566955549343 , Test Accuracy =  0.9373776908023483 , Diff =  2.6279004752585933  %
# Depth =  8 , Training Accuracy =  0.9717640480849874 , Test Accuracy =  0.9347684279191129 , Diff =  3.6995620165874543  %
# Depth =  9 , Training Accuracy =  0.9787531450936539 , Test Accuracy =  0.9262883235485975 , Diff =  5.246482154505639  %
# Depth =  10 , Training Accuracy =  0.9840648588202404 , Test Accuracy =  0.923679060665362 , Diff =  6.038579815487843  %
# Depth =  15 , Training Accuracy =  0.9994408722393067 , Test Accuracy =  0.918460534898891 , Diff =  8.098033734041564  %
# Depth =  20 , Training Accuracy =  1.0 , Test Accuracy =  0.9171559034572733 , Diff =  8.284409654272674  %
# Depth =  25 , Training Accuracy =  1.0 , Test Accuracy =  0.9204174820613177 , Diff =  7.958251793868232  %
# Depth =  30 , Training Accuracy =  1.0 , Test Accuracy =  0.9171559034572733 , Diff =  8.284409654272674  %
# Depth =  35 , Training Accuracy =  1.0 , Test Accuracy =  0.9171559034572733 , Diff =  8.284409654272674  %
# Depth =  40 , Training Accuracy =  1.0 , Test Accuracy =  0.918460534898891 , Diff =  8.153946510110899  %
# Depth =  45 , Training Accuracy =  1.0 , Test Accuracy =  0.9178082191780822 , Diff =  8.21917808219178  %
# Depth =  50 , Training Accuracy =  1.0 , Test Accuracy =  0.9145466405740378 , Diff =  8.545335942596221  %

# %%
# create a model 
dt1 = DecisionTreeClassifier(max_depth = 2, random_state=1)
dt1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=1)

# %%
Y_predt1=dt1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt2=accuracy_score(y_test,Y_predt1)

# %%
ac_dt2
# Out:
# 0.9504240052185258

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred_knn=knn.predict(X_test)

# %%
ac_knn1=accuracy_score(y_test,Y_pred_knn)

# %%
ac_knn1
# Out:
# 0.943900848010437

# %%
# KNN with Euclidean Distance Metric

from sklearn.neighbors import KNeighborsClassifier
numNeighbors = [1, 5, 10, 15, 20, 25, 30,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    knn4 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    knn4.fit(X_train, y_train)
    y_predTrain = knn4.predict(X_train)
    y_predTest = knn4.predict(X_test)
    trainAcc.append(accuracy_score(y_train, y_predTrain))
    testAcc.append(accuracy_score(y_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  0.9112850619699935 , Difference =  8.871493803000652 %
# K =  5 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.943900848010437 , Difference =  0.7455036809244198 %
# K =  10 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  15 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  20 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  25 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  30 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  60 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  100 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  120 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  130 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  140 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  150 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  160 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  200 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %

# %%
# KNN with Manhatten Distance Metric
numNeighbors = [1, 5, 10, 15, 20, 25, 30,40,50,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    knn7 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=1)
    knn7.fit(X_train, y_train)
    y_predTrain = knn7.predict(X_train)
    y_predTest = knn7.predict(X_test)
    trainAcc.append(accuracy_score(y_train, y_predTrain))
    testAcc.append(accuracy_score(y_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  0.9093281148075668 , Difference =  9.067188519243318 %
# K =  5 , Training Accuracy =  0.9519150125803746  Test Accuracy =  0.9458577951728636 , Difference =  0.6057217407510973 %
# K =  10 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  15 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  20 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  25 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  30 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  40 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  50 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  60 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  100 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  120 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  130 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  140 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  150 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  160 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  200 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
lr8 = LogisticRegression(penalty = 'none')

lr8.fit(X_train, y_train)
y_pred_train = lr8.predict(X_train)
y_pred_test = lr8.predict(X_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
print()
ac_lr1 = accuracy_score(y_pred_test, y_test)

lr9 = LogisticRegression(penalty = 'l2')

lr9.fit(X_train, y_train)
y_pred_train = lr9.predict(X_train)
y_pred_test = lr9.predict(X_test)
print("Logistic Regression with L2 regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9497716894977168
#
# Logistic Regression with L2 regularization
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9504240052185258

# %%
ac_lr1
# Out:
# 0.9497716894977168

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred_rf=rf.predict(X_test)

# %%
ac_rf1=accuracy_score(y_test,Y_pred_rf)

# %%
ac_rf1
# Out:
# 0.949119373776908

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.901593514117976
# Test Accuracy:  0.8904109589041096

# %%
ac_perceptron1 = accuracy_score(y_pred_test, y_test)

# %%
ac_perceptron1
# Out:
# 0.8904109589041096

# %%
# Multinomial Naive Bayes

from sklearn.naive_bayes import MultinomialNB
mlf = MultinomialNB()
mlf.fit(X_train, y_train)
y_pred_train = mlf.predict(X_train)
y_pred_test = mlf.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9504240052185258

# %%
ac_naive1 = accuracy_score(y_pred_test, y_test)

# %%
ac_naive1
# Out:
# 0.9504240052185258

# %%
from sklearn.svm import SVC
slf = SVC(gamma = 'auto', random_state = 0)
slf.fit(X_train, y_train)
y_pred_train = slf.predict(X_train)
y_pred_test = slf.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9504240052185258

# %%
# for the SVC classifier
from sklearn import metrics
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1457    0]
#  [  76    0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.950     1.000     0.975      1457
#            1      0.000     0.000     0.000        76
#
#     accuracy                          0.950      1533
#    macro avg      0.475     0.500     0.487      1533
# weighted avg      0.903     0.950     0.926      1533

# %%
ac_svc1 = accuracy_score(y_pred_test, y_test)

# %%
ac_svc1
# Out:
# 0.9504240052185258

# %%
plt.figure(figsize = (10,5))
plt.bar(['Decision Tree ','Logistic','KNN','Random Forest','SVM','Naive Bayes','Perceptron','ZeroR'],[ac_dt2,ac_lr1,ac_knn1,ac_rf1,ac_svc1,ac_naive1,ac_perceptron1,ac_zero1])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # Hyper Parameter Optimization

# %% [markdown]
# # DT HPT

# %%
#Manual

# %%
dt=DecisionTreeClassifier(max_depth=2,criterion= 'gini', min_samples_split= 10, splitter= 'best')
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_split=10)

# %%
prediction=dt.predict(X_test)
accuracy_dt=accuracy_score(y_test,prediction)*100
accuracy_dt
# Out:
# 95.04240052185257

# %%
print("Accuracy on training set: {:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(dt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.952
# Accuracy on test set: 0.950

# %%
accuracy_score(prediction,y_test)
# Out:
# 0.9504240052185258

# %%
#now let's try to do hyperparameter

# %%
dt.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'random_state', 'splitter'])

# %%
#let's try with Randomized Search Cv

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(1, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
splitter = ["best", "random"]
# Create the random grid
random_grid = {'splitter': splitter,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'splitter': ['best', 'random'], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [1, 112, 223, 334, 445, 556, 667, 778, 889, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=DecisionTreeClassifier()
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [1, 112, 223, 334, 445,
#                                                       556, 667, 778, 889,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'splitter': ['best', 'random']},
#                    random_state=100, verbose=2)

# %%
rf_randomcv.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 1,
#  'criterion': 'gini'}

# %%
rf_randomcv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=1, max_features='log2', min_samples_split=5,
#                        splitter='random')

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid.predict(X_test)

print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy Score 0.9504240052185258

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1457    0]
#  [  76    0]]
# 0.9504240052185258
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1457
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %%
#GridSearch CV

# %%
rf_randomcv.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 1,
#  'criterion': 'gini'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'], 
                         rf_randomcv.best_params_['min_samples_leaf']+2, 
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] + 2,
                          rf_randomcv.best_params_['min_samples_split'] + 1,
                          rf_randomcv.best_params_['min_samples_split'], 
                          rf_randomcv.best_params_['min_samples_split'] + 3,
                          rf_randomcv.best_params_['min_samples_split'] + 4],
    'splitter': [rf_randomcv.best_params_['splitter']]}

print(param_grid)
# Out:
# {'criterion': ['gini'], 'max_depth': [1], 'max_features': ['log2'], 'min_samples_leaf': [1, 3, 5], 'min_samples_split': [7, 6, 5, 8, 9], 'splitter': ['random']}

# %%
rf2=DecisionTreeClassifier()
grid_search=GridSearchCV(estimator=rf2,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [1],
#                          'max_features': ['log2'],
#                          'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [7, 6, 5, 8, 9],
#                          'splitter': ['random']},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=1, max_features='log2', min_samples_split=7,
#                        splitter='random')

# %%
best_grid=grid_search.best_estimator_

# %%
best_grid
# Out:
# DecisionTreeClassifier(max_depth=1, max_features='log2', min_samples_split=7,
#                        splitter='random')

# %%
y_pred=best_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[1457    0]
#  [  76    0]]
# Accuracy Score 0.9504240052185258
# Classification report:               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1457
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %% [markdown]
# # KNN HPT

# %%
#Manual

# %%
knn=KNeighborsClassifier(n_neighbors=20, metric='minkowski', p=2)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred1=knn.predict(X_test)
accuracy_knn=accuracy_score(y_test,pred1)*100
accuracy_knn
# Out:
# 95.04240052185257

# %%
print("Accuracy on training set: {:.3f}".format(knn.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(knn.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.952
# Accuracy on test set: 0.950

# %%
accuracy_score(pred1,y_test)
# Out:
# 0.9504240052185258

# %%
#now let's try to do hyperparameter

# %%
knn.get_params().keys()
# Out:
# dict_keys(['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'])

# %%
#let's try with Randomized Search Cv

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
n_neighbors = range(1, 200)
weights = ['uniform', 'distance']
metric = ['euclidean', 'manhattan', 'minkowski']

# Create the random grid
random_grid1 = {'n_neighbors': n_neighbors,
               'weights': weights,
               'metric': metric
               }
print(random_grid1)
# Out:
# {'n_neighbors': range(1, 200), 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan', 'minkowski']}

# %%
rf3=KNeighborsClassifier()
rf3_randomcv=RandomizedSearchCV(estimator=rf3,param_distributions=random_grid1,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf3_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=KNeighborsClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'metric': ['euclidean', 'manhattan',
#                                                    'minkowski'],
#                                         'n_neighbors': range(1, 200),
#                                         'weights': ['uniform', 'distance']},
#                    random_state=100, verbose=2)

# %%
rf3_randomcv.best_params_
# Out:
# {'weights': 'uniform', 'n_neighbors': 152, 'metric': 'minkowski'}

# %%
rf3_randomcv.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=152)

# %%
best_random_grid1=rf3_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid1.predict(X_test)

print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy Score 0.9504240052185258

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1457    0]
#  [  76    0]]
# 0.9504240052185258
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1457
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %%
#GridSearch CV

# %%
rf3_randomcv.best_params_
# Out:
# {'weights': 'uniform', 'n_neighbors': 152, 'metric': 'minkowski'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'weights': [rf3_randomcv.best_params_['weights']],
    
    'n_neighbors': [rf3_randomcv.best_params_['n_neighbors'], 
                         rf3_randomcv.best_params_['n_neighbors']+2, 
                         rf3_randomcv.best_params_['n_neighbors'] + 4,
                   rf3_randomcv.best_params_['n_neighbors']-2, 
                         rf3_randomcv.best_params_['n_neighbors'] - 4],
    'metric': [rf3_randomcv.best_params_['metric']]}

print(param_grid)
# Out:
# {'weights': ['uniform'], 'n_neighbors': [152, 154, 156, 150, 148], 'metric': ['minkowski']}

# %%
rf4=KNeighborsClassifier()
grid_search=GridSearchCV(estimator=rf4,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['minkowski'],
#                          'n_neighbors': [152, 154, 156, 150, 148],
#                          'weights': ['uniform']},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=152)

# %%
best_grid1=grid_search.best_estimator_

# %%
best_grid1
# Out:
# KNeighborsClassifier(n_neighbors=152)

# %%
y_pred4=best_grid1.predict(X_test)
print(confusion_matrix(y_test,y_pred4))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred4)))
print("Classification report: {}".format(classification_report(y_test,y_pred4)))
# Out:
# [[1457    0]
#  [  76    0]]
# Accuracy Score 0.9504240052185258
# Classification report:               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1457
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %% [markdown]
# # Logistic regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
clf6 = LogisticRegression(penalty = 'none')

clf6.fit(X_train, y_train)
y_pred_train = clf6.predict(X_train)
y_pred_test = clf6.predict(X_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
print()
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9497716894977168

# %%
clf6.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.951636 using {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951450 (0.001511) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951450 (0.001511) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951450 (0.001511) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951450 (0.001511) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951450 (0.001511) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951450 (0.001511) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951543 (0.001300) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951543 (0.001300) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951636 (0.001626) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951636 (0.001255) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951636 (0.001255) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951636 (0.001255) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951636 (0.001255) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951636 (0.001255) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951636 (0.001255) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
grid_y_predicted = grid_result.predict(X_test)

# %%
grid_y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
logis_grid_score=accuracy_score(y_test, grid_y_predicted)

# %%
logis_grid_score
# Out:
# 0.9504240052185258

# %%
confusion_matrix(y_test, grid_y_predicted)
# Out:
# array([[1457,    0],
#        [  76,    0]], dtype=int64)

# %%
print(classification_report(y_test,grid_y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1457
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %% [markdown]
# Accuracy did not improve much after hyper parameter tuning

# %% [markdown]
# # With Stratified Train Test split

# %%
from sklearn import metrics

# %% [markdown]
# # With train-test split

# %% [markdown]
# # ZeroR classifier

# %%
# ZeroR classifier

from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score
clf = DummyClassifier(strategy = "most_frequent")
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.9513558848196813
# Test Accuracy:  0.9510763209393346

# %%
ac_zero2 = accuracy_score(y_pred_test, y1_test)

# %%
ac_zero2
# Out:
# 0.9510763209393346

# %%
#As there is class imbalance issue,we need classification report as well

# %%
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y1_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y1_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1458    0]
#  [  75    0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.951     1.000     0.975      1458
#            1      0.000     0.000     0.000        75
#
#     accuracy                          0.951      1533
#    macro avg      0.476     0.500     0.487      1533
# weighted avg      0.905     0.951     0.927      1533

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=dt.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt4=accuracy_score(y1_test,Y_pred)

# %%
ac_dt4
# Out:
# 0.9151989562948467

# %%
# Decision Tree analysis with the depth

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
maxdepths = [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]
trainAcc = np.zeros(len(maxdepths))
testAcc = np.zeros(len(maxdepths))

index = 0
for depth in maxdepths:
    clf = DecisionTreeClassifier(max_depth=depth)
    clf = clf.fit(X1_train, y1_train)
    y_predTrain = clf.predict(X1_train)
    y_predTest = clf.predict(X1_test)
    trainAcc[index] = accuracy_score(y1_train, y_predTrain)
    testAcc[index] = accuracy_score(y1_test, y_predTest)
    print("Depth = ", depth, ", Training Accuracy = ", trainAcc[index], ", Test Accuracy = ", testAcc[index], 
          ", Diff = ", np.abs((trainAcc[index]-testAcc[index])*100), " %")
    index += 1

    
#########################################
# Plot of training and test accuracies
#########################################
    
plt.plot(maxdepths,trainAcc,'ro-',maxdepths,testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy');
# Out:
# Depth =  2 , Training Accuracy =  0.9513558848196813 , Test Accuracy =  0.9510763209393346 , Diff =  0.027956388034666713  %
# Depth =  3 , Training Accuracy =  0.9513558848196813 , Test Accuracy =  0.9510763209393346 , Diff =  0.027956388034666713  %
# Depth =  4 , Training Accuracy =  0.9524741403410679 , Test Accuracy =  0.9445531637312459 , Diff =  0.792097660982205  %
# Depth =  5 , Training Accuracy =  0.9558289069052278 , Test Accuracy =  0.9484670580560991 , Diff =  0.7361848849128716  %
# Depth =  6 , Training Accuracy =  0.9577858540676545 , Test Accuracy =  0.9465101108936725 , Diff =  1.1275743173981945  %
# Depth =  7 , Training Accuracy =  0.9633771316745876 , Test Accuracy =  0.9386823222439661 , Diff =  2.4694809430621523  %
# Depth =  8 , Training Accuracy =  0.9686888454011742 , Test Accuracy =  0.9328114807566862 , Diff =  3.5877364644487986  %
# Depth =  9 , Training Accuracy =  0.974559686888454 , Test Accuracy =  0.9308545335942596 , Diff =  4.370515329419433  %
# Depth =  10 , Training Accuracy =  0.9829466032988537 , Test Accuracy =  0.9210697977821265 , Diff =  6.187680551672726  %
# Depth =  15 , Training Accuracy =  0.9986021805982667 , Test Accuracy =  0.91324200913242 , Diff =  8.536017146584662  %
# Depth =  20 , Training Accuracy =  1.0 , Test Accuracy =  0.9119373776908023 , Diff =  8.80626223091977  %
# Depth =  25 , Training Accuracy =  1.0 , Test Accuracy =  0.91324200913242 , Diff =  8.675799086757996  %
# Depth =  30 , Training Accuracy =  1.0 , Test Accuracy =  0.9080234833659491 , Diff =  9.197651663405093  %
# Depth =  35 , Training Accuracy =  1.0 , Test Accuracy =  0.91324200913242 , Diff =  8.675799086757996  %
# Depth =  40 , Training Accuracy =  1.0 , Test Accuracy =  0.9080234833659491 , Diff =  9.197651663405093  %
# Depth =  45 , Training Accuracy =  1.0 , Test Accuracy =  0.9099804305283757 , Diff =  9.001956947162427  %
# Depth =  50 , Training Accuracy =  1.0 , Test Accuracy =  0.9119373776908023 , Diff =  8.80626223091977  %

# %%
# create a model 
dt5 = DecisionTreeClassifier(max_depth = 2, random_state=1)
dt5.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=1)

# %%
Y_predt1=dt5.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt2=accuracy_score(y1_test,Y_predt1)

# %%
ac_dt2
# Out:
# 0.9510763209393346

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred_knn=knn.predict(X1_test)

# %%
ac_knn1=accuracy_score(y1_test,Y_pred_knn)

# %%
ac_knn1
# Out:
# 0.9465101108936725

# %%
# KNN with Euclidean Distance Metric

from sklearn.neighbors import KNeighborsClassifier
numNeighbors = [1, 5, 10, 15, 20, 25, 30,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    clf = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    clf.fit(X1_train, y1_train)
    y_predTrain = clf.predict(X1_train)
    y_predTest = clf.predict(X1_test)
    trainAcc.append(accuracy_score(y1_train, y_predTrain))
    testAcc.append(accuracy_score(y1_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  0.918460534898891 , Difference =  8.153946510110899 %
# K =  5 , Training Accuracy =  0.9538719597428013  Test Accuracy =  0.9465101108936725 , Difference =  0.7361848849128716 %
# K =  10 , Training Accuracy =  0.9524741403410679  Test Accuracy =  0.9504240052185258 , Difference =  0.20501351225421516 %
# K =  15 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  20 , Training Accuracy =  0.9516354487000279  Test Accuracy =  0.9504240052185258 , Difference =  0.12114434815021502 %
# K =  25 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  30 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  60 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  100 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  120 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  130 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  140 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  150 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  160 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  200 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %

# %%
# KNN with Manhatten Distance Metric
numNeighbors = [1, 5, 10, 15, 20, 25, 30,40,50,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    clf = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=1)
    clf.fit(X1_train, y1_train)
    y_predTrain = clf.predict(X1_train)
    y_predTest = clf.predict(X1_test)
    trainAcc.append(accuracy_score(y1_train, y_predTrain))
    testAcc.append(accuracy_score(y1_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  0.9204174820613177 , Difference =  7.958251793868232 %
# K =  5 , Training Accuracy =  0.9535923958624546  Test Accuracy =  0.9445531637312459 , Difference =  0.9039232131208719 %
# K =  10 , Training Accuracy =  0.9521945764607213  Test Accuracy =  0.9504240052185258 , Difference =  0.17705712421954845 %
# K =  15 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  20 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  25 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  30 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  40 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  50 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  60 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  100 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  120 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  130 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  140 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  150 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  160 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %
# K =  200 , Training Accuracy =  0.9513558848196813  Test Accuracy =  0.9510763209393346 , Difference =  0.027956388034666713 %

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
lr2 = LogisticRegression(penalty = 'none')

lr2.fit(X1_train, y1_train)
y_pred_train = lr2.predict(X1_train)
y_pred_test = lr2.predict(X1_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
print()
ac_lr1 = accuracy_score(y_pred_test, y1_test)

clf = LogisticRegression(penalty = 'l2')

clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Logistic Regression with L2 regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9504240052185258
#
# Logistic Regression with L2 regularization
# Train Accuracy:  0.9513558848196813
# Test Accuracy:  0.9510763209393346

# %%
ac_lr1
# Out:
# 0.9504240052185258

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X1_train,y1_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred_rf=rf.predict(X1_test)

# %%
ac_rf1=accuracy_score(y1_test,Y_pred_rf)

# %%
ac_rf1
# Out:
# 0.9471624266144814

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.8705619233994968
# Test Accuracy:  0.8851924331376386

# %%
ac_perceptron1 = accuracy_score(y_pred_test, y1_test)

# %%
ac_perceptron1
# Out:
# 0.8851924331376386

# %%
# Multinomial Naive Bayes

from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.7945205479452054
# Test Accuracy:  0.8003913894324853

# %%
ac_naive1 = accuracy_score(y_pred_test, y1_test)

# %%
ac_naive1
# Out:
# 0.8003913894324853

# %%
from sklearn.svm import SVC
clf = SVC(gamma = 'auto', random_state = 0)
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.9603019289907744
# Test Accuracy:  0.9504240052185258

# %%
# for the SVC classifier
from sklearn import metrics
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y1_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y1_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1456    2]
#  [  74    1]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.952     0.999     0.975      1458
#            1      0.333     0.013     0.026        75
#
#     accuracy                          0.950      1533
#    macro avg      0.642     0.506     0.500      1533
# weighted avg      0.921     0.950     0.928      1533

# %%
ac_svc1 = accuracy_score(y_pred_test, y1_test)

# %%
ac_svc1
# Out:
# 0.9504240052185258

# %%
plt.figure(figsize = (10,5))
plt.bar(['Decision Tree ','Logistic','KNN','Random Forest','SVM','Naive Bayes','Perceptron','ZeroR'],[ac_dt4,ac_lr1,ac_knn1,ac_rf1,ac_svc1,ac_naive1,ac_perceptron1,ac_zero2])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # Hyper Parameter Optimization

# %% [markdown]
# # DT HPT

# %%
#Manual

# %%
dt=DecisionTreeClassifier(max_depth=2,criterion= 'gini', min_samples_split= 10, splitter= 'best')
dt.fit(X1_train,y1_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_split=10)

# %%
prediction=dt.predict(X1_test)
accuracy_dt=accuracy_score(y1_test,prediction)*100
accuracy_dt
# Out:
# 95.10763209393346

# %%
print("Accuracy on training set: {:.3f}".format(dt.score(X1_train, y1_train)))
print("Accuracy on test set: {:.3f}".format(dt.score(X1_test, y1_test)))
# Out:
# Accuracy on training set: 0.951
# Accuracy on test set: 0.951

# %%
accuracy_score(prediction,y1_test)
# Out:
# 0.9510763209393346

# %%
#now let's try to do hyperparameter

# %%
dt.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'random_state', 'splitter'])

# %%
#let's try with Randomized Search Cv

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(1, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
splitter = ["best", "random"]
# Create the random grid
random_grid = {'splitter': splitter,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'splitter': ['best', 'random'], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [1, 112, 223, 334, 445, 556, 667, 778, 889, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=DecisionTreeClassifier()
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(X1_train,y1_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [1, 112, 223, 334, 445,
#                                                       556, 667, 778, 889,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'splitter': ['best', 'random']},
#                    random_state=100, verbose=2)

# %%
rf_randomcv.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 14,
#  'min_samples_leaf': 6,
#  'max_features': 'log2',
#  'max_depth': 667,
#  'criterion': 'gini'}

# %%
rf_randomcv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=667, max_features='log2', min_samples_leaf=6,
#                        min_samples_split=14, splitter='random')

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid.predict(X1_test)

print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy Score 0.9504240052185258

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(confusion_matrix(y1_test,y_pred))
print(accuracy_score(y1_test,y_pred))
print(classification_report(y1_test,y_pred))
# Out:
# [[1458    0]
#  [  75    0]]
# 0.9510763209393346
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1458
#            1       0.00      0.00      0.00        75
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %%
#GridSearch CV

# %%
rf_randomcv.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 14,
#  'min_samples_leaf': 6,
#  'max_features': 'log2',
#  'max_depth': 667,
#  'criterion': 'gini'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'], 
                         rf_randomcv.best_params_['min_samples_leaf']+2, 
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] + 2,
                          rf_randomcv.best_params_['min_samples_split'] + 1,
                          rf_randomcv.best_params_['min_samples_split'], 
                          rf_randomcv.best_params_['min_samples_split'] + 3,
                          rf_randomcv.best_params_['min_samples_split'] + 4],
    'splitter': [rf_randomcv.best_params_['splitter']]}

print(param_grid)
# Out:
# {'criterion': ['gini'], 'max_depth': [667], 'max_features': ['log2'], 'min_samples_leaf': [6, 8, 10], 'min_samples_split': [16, 15, 14, 17, 18], 'splitter': ['random']}

# %%
rf2=DecisionTreeClassifier()
grid_search=GridSearchCV(estimator=rf2,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X1_train,y1_train)
# Out:
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [667],
#                          'max_features': ['log2'],
#                          'min_samples_leaf': [6, 8, 10],
#                          'min_samples_split': [16, 15, 14, 17, 18],
#                          'splitter': ['random']},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=667, max_features='log2', min_samples_leaf=10,
#                        min_samples_split=16, splitter='random')

# %%
best_grid=grid_search.best_estimator_

# %%
best_grid
# Out:
# DecisionTreeClassifier(max_depth=667, max_features='log2', min_samples_leaf=10,
#                        min_samples_split=16, splitter='random')

# %%
y_pred=best_grid.predict(X1_test)
print(confusion_matrix(y1_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y1_test,y_pred)))
print("Classification report: {}".format(classification_report(y1_test,y_pred)))
# Out:
# [[1458    0]
#  [  75    0]]
# Accuracy Score 0.9510763209393346
# Classification report:               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1458
#            1       0.00      0.00      0.00        75
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %% [markdown]
# # KNN HPT

# %%
#Manual

# %%
knn=KNeighborsClassifier(n_neighbors=10, metric='minkowski', p=1)
knn.fit(X1_train,y1_train)
# Out:
# KNeighborsClassifier(n_neighbors=10, p=1)

# %%
pred1=knn.predict(X1_test)
accuracy_knn=accuracy_score(y1_test,pred1)*100
accuracy_knn
# Out:
# 95.04240052185257

# %%
print("Accuracy on training set: {:.3f}".format(knn.score(X1_train, y1_train)))
print("Accuracy on test set: {:.3f}".format(knn.score(X1_test, y1_test)))
# Out:
# Accuracy on training set: 0.952
# Accuracy on test set: 0.950

# %%
accuracy_score(pred1,y1_test)
# Out:
# 0.9504240052185258

# %%
#now let's try to do hyperparameter

# %%
knn.get_params().keys()
# Out:
# dict_keys(['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'])

# %%
#let's try with Randomized Search Cv

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
n_neighbors = range(1, 200)
weights = ['uniform', 'distance']
metric = ['euclidean', 'manhattan', 'minkowski']

# Create the random grid
random_grid1 = {'n_neighbors': n_neighbors,
               'weights': weights,
               'metric': metric
               }
print(random_grid1)
# Out:
# {'n_neighbors': range(1, 200), 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan', 'minkowski']}

# %%
rf3=KNeighborsClassifier()
rf3_randomcv=RandomizedSearchCV(estimator=rf3,param_distributions=random_grid1,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf3_randomcv.fit(X1_train,y1_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=KNeighborsClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'metric': ['euclidean', 'manhattan',
#                                                    'minkowski'],
#                                         'n_neighbors': range(1, 200),
#                                         'weights': ['uniform', 'distance']},
#                    random_state=100, verbose=2)

# %%
rf3_randomcv.best_params_
# Out:
# {'weights': 'uniform', 'n_neighbors': 9, 'metric': 'euclidean'}

# %%
rf3_randomcv.best_estimator_
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=9)

# %%
best_random_grid1=rf3_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid1.predict(X1_test)

print("Accuracy Score {}".format(accuracy_score(y1_test,y_pred)))
# Out:
# Accuracy Score 0.9484670580560991

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(confusion_matrix(y1_test,y_pred))
print(accuracy_score(y1_test,y_pred))
print(classification_report(y1_test,y_pred))
# Out:
# [[1453    5]
#  [  74    1]]
# 0.9484670580560991
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1458
#            1       0.17      0.01      0.02        75
#
#     accuracy                           0.95      1533
#    macro avg       0.56      0.50      0.50      1533
# weighted avg       0.91      0.95      0.93      1533

# %%
#GridSearch CV

# %%
rf3_randomcv.best_params_
# Out:
# {'weights': 'uniform', 'n_neighbors': 9, 'metric': 'euclidean'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'weights': [rf3_randomcv.best_params_['weights']],
    
    'n_neighbors': [rf3_randomcv.best_params_['n_neighbors'], 
                         rf3_randomcv.best_params_['n_neighbors']+2, 
                         rf3_randomcv.best_params_['n_neighbors'] + 4,
                   rf3_randomcv.best_params_['n_neighbors']-2, 
                         rf3_randomcv.best_params_['n_neighbors'] - 4],
    'metric': [rf3_randomcv.best_params_['metric']]}

print(param_grid)
# Out:
# {'weights': ['uniform'], 'n_neighbors': [9, 11, 13, 7, 5], 'metric': ['euclidean']}

# %%
rf4=KNeighborsClassifier()
grid_search=GridSearchCV(estimator=rf4,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X1_train,y1_train)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean'],
#                          'n_neighbors': [9, 11, 13, 7, 5],
#                          'weights': ['uniform']},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=13)

# %%
best_grid1=grid_search.best_estimator_

# %%
best_grid1
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=13)

# %%
y_pred4=best_grid1.predict(X1_test)
print(confusion_matrix(y_test,y_pred4))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred4)))
print("Classification report: {}".format(classification_report(y_test,y_pred4)))
# Out:
# [[1454    3]
#  [  76    0]]
# Accuracy Score 0.9484670580560991
# Classification report:               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1457
#            1       0.00      0.00      0.00        76
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %% [markdown]
# # Logistic regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
clf6 = LogisticRegression(penalty = 'none')

clf6.fit(X1_train, y1_train)
y_pred_train = clf6.predict(X1_train)
y_pred_test = clf6.predict(X1_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
print()
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9516354487000279
# Test Accuracy:  0.9504240052185258

# %%
clf6.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X1_train, y1_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.951357 using {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951357 (0.001337) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951077 (0.001698) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951357 (0.001337) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951357 (0.001337) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.950984 (0.001840) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951357 (0.001337) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951357 (0.001337) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951171 (0.001537) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951171 (0.001537) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951357 (0.001337) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951357 (0.001337) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.951077 (0.001852) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.951357 (0.001337) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951357 (0.001337) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.950425 (0.002011) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
grid_y_predicted = grid_result.predict(X1_test)

# %%
grid_y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
logis_grid_score=accuracy_score(y1_test, grid_y_predicted)

# %%
logis_grid_score
# Out:
# 0.9510763209393346

# %%
confusion_matrix(y1_test, grid_y_predicted)
# Out:
# array([[1458,    0],
#        [  75,    0]], dtype=int64)

# %%
print(classification_report(y1_test,grid_y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1458
#            1       0.00      0.00      0.00        75
#
#     accuracy                           0.95      1533
#    macro avg       0.48      0.50      0.49      1533
# weighted avg       0.90      0.95      0.93      1533

# %% [markdown]
# Accuracy did not improve much after hyper parameter tuning
